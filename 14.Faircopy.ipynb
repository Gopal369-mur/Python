# %%
#from libraray import the class
from Multiplefunction import multiplefunction


#classname.function name
multiplefunction.Eligibilityformarriage()
# Out:
# Enter the Gender:  male
# Enter the age: 29
# you are eligible for marriage

# %%
multiplefunction.oddeven()
# Out:
# Enter the number:  24
# 24 is even number
# 'is even number '
