# %%
#1.What is wrong with the following function definition, and how do you fix it?

# 1: is missing, add the return statement with function name and call the function with respective arguments
def say_hello(name):
    print("Hello, " + name)
    return say_hello

say_hello("Gopal")
# Out:
# Hello, Gopal
# <function __main__.say_hello(name)>

# %%
#2.What error will occur in the following code, and how do you fix it?

#remove the symbol + instaed of that add comma 
age = 25
print("I am " , age ,  " years old")
# Out:
# I am  25  years old

# %%
#3.Question:
What is the issue with the following code?

#variabel not declared in first line of function, return function not mentioned, 
def greet(greet):
    message = "Hello"
    return greet
greet("hello")
# Out:
# Object `code` not found.
# 'hello'

# %%
#4.What error will occur in the following code, and how do you fix it?

#only one argument is available instead of 2 arguments

def add(a, b):
    return a + b

print(add(5, 3))
# Out:
# 8

# %%
#5.What is wrong with this code?

#code tried with 2 input one is 2 and another one is 2 for 2 its shows false, for input 3 it shows true, hence code is correct
# explanation 2%2 = 0 which is not equal to 1 hence false is the result
#for input 3, 3%2 = 1... which is equalto 1 hence true is the result

def is_even(n):
    if n % 2 == 1:
        return True
    else:
        return False

is_even(3)
# Out:
# True

# %%
#6.What happens when you run this code?

num = int("10a")
print(num)

#10a is not integer, hecne numeric error will appear
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 #6.What happens when you run this code?
# ----> 3 num = int("10a")
#       4 print(num)
#       6 #10a is not integer, hecne numeric error will appear
#
# ValueError: invalid literal for int() with base 10: '10a'

# %%
7.What will happen when you run the following code?

numbers = [1, 2, 3, 4]
numbers.reverse()
print(numbers)

#sort is removed, only revers is used

#output could be [4, 3, 2, 1]
# Out:
# Object `code` not found.
# [4, 3, 2, 1]

# %%
#8.What is the issue with this code?

#in output number 4 will be added into list

numbers = [1, 2, 3]
numbers = numbers.append(4)
print(numbers)
# Out:
# None

# %%
#9.What will happen when you run the following code?

#Add the vairiable and call the function with argumentss

count = 10

def increment(count):
    count += 1
    print(count)

increment(10)
# Out:
# 11

# %%
#10.What error will occur in the following code?

# only 5 index ar there so error will appear for shortage of index
text = "Python"
print(text[5])
# Out:
# n
