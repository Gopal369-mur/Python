# %%
#1.Find the error in the following Python code:

#correct the space adn add the colon at end of for loop

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

# remove the "5" and make into 5

a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
#3.What is the issue in this Python snippet?

#correct the space and add the colon at end of function

def add_numbers(a, b):
    return a + b
add_numbers(5,5)
# Out:
# 10

# %%
#4.Identify the bug in the following Python code:

#correct the space and mention the index within list,numbers [4] is the out of index, because only 3 index are there

numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:

#keep the helloworld ()

print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:give

# 5/0 gives 0, it is zerodivision error
x = 5 / 1
print(x)
# Out:
# 5.0

# %%
#7.Find the error in the following Python code:name = "Alice"

#add the variable name and assign the string "Alice" to name variable, remove the + 
age = 25
name = "Alice"
print("Name: " , name , ", Age: " ,age)
# Out:
# Name:  Alice , Age:  25

# %%
#8.Find the error

#-1 indicate negative so change the -1 into 1

for i in range(1, 10, 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#9. Find the error in the following Python code:

# if condition is failed, so else condition written

x = 10
if x == 5:
    print("x is 5")
else:
    print("x is 10")
# Out:
# x is 10

# %%
#10. Identify the error in the following function definition:

#add colon at end of function, 

def greet(name):
    return ("Hello, " + name)
greet("Gokul")
# Out:
# 'Hello, Gokul'
