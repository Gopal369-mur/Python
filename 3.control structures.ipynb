# %%
age=input("Enter the age")
if(age==18):
    print('adult')
# Out:
# Enter the age 18

# %%
age=int(input("Enter the age"))
if(age==18):
    print('adult')
# Out:
# Enter the age 8

# %%
age=int(input("Enter the age"))
if(age==18):
    print('adult')
# Out:
# Enter the age 18
# adult

# %%
age=int(input("Enter the age"))
if(age<18):
    print("children")
else:
    print("adult")
# Out:
# Enter the age 12
# children

# %%
age=int(input("Enter the age"))
if(age<18):
    print("children")
else:
    print("adult")
# Out:
# Enter the age 18
# adult

# %%
age=int(input("Enter the age"))
if(age<=18):
    print("children")
else:
    print("adult")
# Out:
# Enter the age 18
# children

# %%
age=int(input("Enter the age"))
if(age<=18):
    print("children")
else:
    print("adult")
# Out:
# Enter the age 19
# adult

# %%
age=int(input("Enter the age"))
if(age<18):
    print("children")
elif(age<35):
    print("Adult")
elif(age<65):
    print("citizen")
else:
    print("senior citizen")
# Out:
# Enter the age 10
# children

# %%
age=int(input("Enter the age"))
if(age<18):
    print("children")
elif(age<35):
    print("Adult")
elif(age<65):
    print("citizen")
else:
    print("senior citizen")
# Out:
# Enter the age 64
# citizen

# %%
age=int(input("Enter the age"))
if(age<18):
    print("children")
elif(age<35):
    print("Adult")
elif(age<65):
    print("citizen")
else:
    print("senior citizen")
# Out:
# Enter the age 67
# senior citizen

# %%
age=int(input("Enter the age"))
if(age<18):
    print("children")
elif(age<35):
    print("Adult")
elif(age<65):
    print("citizen")
else:
    print("senior citizen")
# Out:
# Enter the age 23
# Adult

# %%
age=[25,25,45,36,67]
for status in age:
    print(status)
# Out:
# 25
# 25
# 45
# 36
# 67

# %%
age=[25,25,45,36,67]
for status in age:
    if(status<18):
        print("Children")
    elif(status<35):
        print("adult" )
    elif (status<60):
        print("Citizen" )
    else:
        print ("Senior citizen")
# Out:
# adult
# adult
# Citizen
# Citizen
# Senior citizen
