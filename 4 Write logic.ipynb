# %%
num=int(input("Enter the number:"))
if((num%2)==0):
    print("Even number")
else:
    print('odd number')
# Out:
# Enter the number: 5
# odd number

# %%
num=int(input("Enter the number:"))
if((num%2)==0):
    print("Even number")
else:
    print('odd number')
# Out:
# Enter the number: 4
# Even number

# %%
num=int(input("Enter the number:"))
if((num%2)==0):
    print("Even number")
else:
    print('odd number')
# Out:
# Enter the number: 2
# Even number

# %%
num=int(input("Enter the number:"))
if((num%2)==1):
    print("odd number")
else:
    print('even number')
# Out:
# Enter the number: 2
# even number

# %%
num=int(input("Enter the number:"))
if((num%2)==1):
    print("odd number")
else:
    print('even number')
# Out:
# Enter the number: 5
# odd number
