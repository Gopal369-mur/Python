# %%
#1.Find the error in the following Python code:

# change the Math into math


import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:

#Change the x+=5 into x==5

def my_function():
    x == 5
    print(x)

x = 10
my_function()
# Out:
# 10

# %%
#3.x = 5

# add one more = 
if x == 10:
    print("x is 10")
# Out:
# x is 10

# %%
#4.
numbers = [5, 3, 8, 2]
numbers.sort()
print (numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5
def square(n):
    return n*n
print(square(4))
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #6.
#       2 my_tuple = (1, 2, 3)
# ----> 3 my_tuple[1] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
#7.
#add the respective variable in print statement
name = "Alice"
age = 25

print("My name is", name, "and I am", age, "years old")
# Out:
# My name is Alice and I am 25 years old

# %%
#8.

#add equal sign remoe is
a = [1, 2, 3]
b = [1, 2, 3]
if a==b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
#changed the start stop 
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 3
#       1 #10.
#       2 student = {"name": "John", "age": 20}
# ----> 3 print(student[name])
#
# KeyError: 'Alice'
