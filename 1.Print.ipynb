# %%
print ()

# %%
print("Artificial Intelligence")
# Out:
# Artificial Intelligence

# %%
print('artificial intelligence')
# Out:
# artificial intelligence

# %%
print('1 Module completed')
# Out:
# 1 Module completed
