# %%
print('Welcome to assignment-1')
# Out:
# Welcome to assignment-1

# %%
num1=10
num2=30
add=num1+num2
print("Num1=", num1)
print("Num2=", num2)
print("Add=", add)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
#Body Mass Index - Underweight<18.5, Nomral weight-18.5-24.9 overweight-25-29.9, obesity:30, Divide the person weight in kg/height in metre
#BMI not cover muscle mass, bone density or body composition.
cool=int(input("Enter the BMI index:"))
if(cool>=30):
    print("very Overweight")
# Out:
# Enter the BMI index: 34
# very Overweight

# %%
#Mild advanced version
name=str(input("Enter the Person name"))
height=float(input("Enter the height"))
weight=int(input("Enter the weight"))
Bmi=weight / height*height
if(Bmi<=18.5):
    print("Underweight", Bmi)
# Out:
# Enter the Person name Gopal K
# Enter the height 5.5
# Enter the weight 5
# Underweight 5.0

# %%
#learned python priority from this logic mistake in formula -  * and / have same priority, need to mention inside () for first calculation
name=str(input("Enter the Person name"))
height=float(input("Enter the height"))
weight=int(input("Enter the weight"))
Bmi=weight / height*height
if(Bmi<=18.5):
    print("Underweight", Bmi)
# Out:
# Enter the Person name Gopal K
# Enter the height 5.5
# Enter the weight 50

# %%
#Correct mild advanced version
name=str(input("Enter the Person name"))
height=float(input("Enter the height"))
weight=int(input("Enter the weight"))
Bmi=weight / (height **2)
if(Bmi<=18.5):
    print("Underweight", Bmi)
# Out:
# Enter the Person name Gopal K
# Enter the height 5.5
# Enter the weight 52
# Underweight 1.71900826446281

# %%
#Final correct version
name=str(input("Enter the name"))
height_Cm=float(input("Enter the height in cm:"))
weight_kg=float(input("Enter the weight in kg:"))

#Convert the height from cm into metre
height_m=height_Cm/100

bmi=weight_kg/(height_m**2)

if bmi<=18.5:
    print("Underweight", bmi)
elif(bmi<=24.9):
    print("Normal weight", bmi)
elif(bmi<=29.9):
    print("over weight", bmi)
else:
    print("obese", bmi)
# Out:
# Enter the name Gopal k
# Enter the height in cm: 180
# Enter the weight in kg: 52
# Underweight 16.049382716049383
