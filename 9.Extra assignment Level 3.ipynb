# %%
#print 'CORRECT' if i==10

a =int(input("value:" ) )
if a==10:
    print("Correct")
# Out:
# value: 10
# Correct

# %%
#Check the password, using if and else

pwd = input("Enter the password: ")
if pwd == "HOPE@123":
    print("Password is correct" )
else:
    print("wrong password")
# Out:
# Enter the password:  HOPE@123
# Password is correct

# %%
#category the pople by their age like childre, adult, citizen, senior citizen
#below 18 children, above 18 are adult, 18 - 60 citizen and above 60 are senior citizen


name = str(input("Enter the person name:") )
age = int(input ("Enter the age: "))

if age <=18:
    print("children")
elif age <= 35:
    print("adult")
elif age <=60:
    print("Citizen")
else:
    print("Senior citizen")
# Out:
# Enter the person name: Gopal K
# Enter the age:  20
# adult

# %%
personage =int(input("Enter the age")) 
if personage <= 18:
    print("children")
elif personage <= 35:
    print("adult")
elif personage <=60:
    print("Citizen")
else:
    print("Senior citizen")
# Out:
# Enter the age 55
# Citizen

# %%
#Find whether given number is postive or negative
num = int(input("Enter any number:"))
if num > 0:
    print("No is positive")
else:
    print (" No is Negative")
# Out:
# Enter any number: 1
# No is positive

# %%
#Check whether the give number is divisible by 5
num = int(input("enter the number to check:" ))

if num%5 == 0:
    print("No is divisible by 5")
else:
    print("No is not divisible by 5")
# Out:
# enter the number to check: 22
# No is not divisible by 5
