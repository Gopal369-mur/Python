# %%
def addition(a,b):
    addition=a+b
    return addition

# %%
lists = [23, 45, 67, 34, 89 ]
def Agecategory():
    for age in lists:
        if(age<18):
            print("Children")
        elif (age<35):
            print(" Adult")
        elif(age<59):
            print("Citizen")
        else:
            print("senior citizen")
Agecategory()
# Out:
#  Adult
# Citizen
# senior citizen
#  Adult
# senior citizen

# %%
def Agecategory():
        if(age<18):
            print("Children")
            cate ="Children"
        elif (age<35):
            print(" Adult")
            cate = "Adult"
        elif(age<59):
            print("Citizen")
            Cate = "Citizen "
        else:
            print("senior citizen")
            cate ="Senior citizen"
        return cate

# %%
age = int(input("Enter the age:"))
agecate=Agecategory()
# Out:
# Enter the age: 60
# senior citizen

# %%
print(agecate)
# Out:
# Senior citizen

# %%
def oddeven():
    a=int(input("Enter the number: "))
    if(a%2==1):
        print("odd number")
        message = "odd number "
    else:
        print("Even number")
        message = "Even number"
    return message

# %%
oddeven()
# Out:
# Enter the number:  9
# odd number
# 'odd number '

# %%
def BMI():
    index=int(input("Enter the BMI index: "))
    if index < 18.5:
        print("Underweight")
        message = "uderweight"
    elif index < 24.9:
        print("Normal")
        message = "Normal"
    elif index < 29.9:
        print ("Overweight")
        message = "Overweight"
    else:
        print("Very Overweight")
        message = " Very overweight "
    return message
BMI()
# Out:
# Enter the BMI index:  43
# Very Overweight
# ' Very overweight '

# %%
#parameterized function is used for cut the interaction from user

def addition (num1, num2):
    add = num1 + num2
    return add

addition(4, 5)
# Out:
# 9
