# %%
num1=10
num2=20
add=num1+num2
print(add)
print("add")
# Out:
# 30
# add

# %%
num3=49
num4=55
cool=num3+num4
hot=num3-num4
print(cool)
print(hot)
# Out:
# 104
# -6

# %%
first name="Gopal K"
print(first name)
# Out:
#   Cell In[11], line 1
#     first name="Gopal K"
#           ^
# SyntaxError: invalid syntax

# %%
first_name="Gopal K"
print(first_name)
# Out:
# Gopal K

# %%
firstname="Gopal k"
print(firstname)
# Out:
# Gopal k

# %%
f2irstname ="Gopal k"
print(f2irstname)
# Out:
# Gopal k

# %%
print("The additon of two numbers")
number1=10
number2=20
The_answer_is=number1+number2
print(number1)
print(number2)
print(The_answer_is)
# Out:
# The additon of two numbers
# 10
# 20
# 30

# %%
print("The additon of two numbers")
number1=10
number2=20
The_answer_is=number1+number2
print("The number 1=", number1)
print("The number 2=", number2)
print("THe answer is=",The_answer_is)
# Out:
# The additon of two numbers
# The number 1= 10
# The number 2= 20
# THe answer is= 30

# %%
num1=input("Enter the nnumber 1:")
num2=input("Enter the number 2:")
# Out:
# Enter the nnumber 1: 10
# Enter the number 2: 10

# %%
num1=input('Enter the number 1')
# Out:
# Enter the number 1 10

# %%
num2=input("Enter the number 2")
# Out:
# Enter the number 2 20

# %%
add=num1+num2

# %%
print(add)
# Out:
# 1020

# %%
num1=int(input('enter the number1:'))
# Out:
# enter the number1: 10

# %%
num2=int(input('enter the number 2:'))
# Out:
# enter the number 2: 20

# %%
add=num1+num2

# %%
print(add)
# Out:
# 30
